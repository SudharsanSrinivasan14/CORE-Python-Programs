# %% [markdown]
# <a href="https://colab.research.google.com/github/SudharsanSrinivasan14/Python-Programs/blob/main/Food_Order.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('\t\t\twelcome to')
print('\t\t\tSUDHAN FOOD')
print('\t\t\t...Thank You For Choosing Us...')
print('\n\t\t\tPlease Select Options')

print("""\t\t\t1. Tiffin
      \t\t\t2. Lunch
      \t\t\t3. Dinner """)

s=int(input('Give Your Options : '))
if(s==1):
    print('\n\t\t\tTiifin')
    print('\t\t\tPlease Select Options')

    print("""\n\t\t\t\t1. Idly
          \t\t\t2. Dosa
          \t\t\t3. Pongal
          \t\t\t4. Poori
          \t\t\t5. Chapati """)
    s=int(input('Give Your Options : '))
    if (s==1):
        print('\n\t\t\tIdly')
        print('\t\t\tPlease Select Options')

        print("""\n\t\t\t\t1. Rice Idly
              \t\t\t2. Rava Idly
              \t\t\t3. Samba Idly""")

        if (s==1):
            print('\n\t\t\tRice Idly')
            print('\t\t\tPlease Select Orders : Rice Idly / 10.Rs')

            a=int(input('Give Your Count : '))
            ip = a*10
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', ip + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', ip, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==2):
            print('\n\t\t\tRava Idly')
            print('\t\t\tPlease Select Orders : Rava Idly / 15.Rs')

            a=int(input('Give Your Count : '))
            rdp = a*15
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', rdp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', rdp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==3):
            print('\n\t\t\tSamba Idly')
            print('\t\t\tPlease Select Orders : Samba Idly / 20.Rs')

            a=int(input('Give Your Count : '))
            sdp = a*20
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', sdp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', sdp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')


        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==2):
        print('\n\t\t\tDosa')
        print('\t\t\tPlease Select Options')

        print("""\n\t\t\t\t1. Ordinary Dosa
              \t\t\t2. Rava Dosa
              \t\t\t3. Ghee Dosa
              \t\t\t4. Onion Dosa
              \t\t\t5. Spl. Dosa""")

        if (s==1):
            print('\n\t\t\tOrdinary Dosa')
            print('\t\t\tPlease Select Orders : Ordinary Dosa / 30.Rs')

            d=int(input('Give Your Count : '))
            dp = d*10
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', dp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', dp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==2):
            print('\n\t\t\tRava Dosa')
            print('\t\t\tPlease Select Orders : Rava Dosa / 30.Rs')

            a=int(input('Give Your Count : '))
            rd = a*30
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= v * 10
                print('Your Order Details: ', rd + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', rd, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==3):

            print('\n\t\t\tGhee Dosa')
            print('\t\t\tPlease Select Orders : Ghee Dosa / 45.Rs')

            a=int(input('Give Your Count : '))
            gd = a*45
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= v * 10
                print('Your Order Details: ', gd + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', gd, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==4):
            print('\n\t\t\tOnion Dosa')
            print('\t\t\tPlease Select Orders : Onion Dosa / 40.Rs')

            a=int(input('Give Your Count : '))
            od = a*40
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', od + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', od, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==5):
            print('\n\t\t\tSpl. Dosa')
            print('\t\t\tPlease Select Orders : Spl. Dos / 50.Rs')

            a=int(input('Give Your Count : '))
            spd = a*50
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', spd + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', spd, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')


        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==3):
        print('\n\t\t\tPongal')
        print('\t\t\tPlease Select Options')

        print("""\n\t\t\t1. Rice Pongal
              \t\t\t2. Rava Pongal
              \t\t\t3. Samba Pongal""")

        if (s==1):
            print('\n\t\t\tRice Pongal')
            print('\t\t\tPlease Select Orders : Rice Pongal / 30.Rs')

            a=int(input('Give Your Count : '))
            rcp = a*30
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', rcp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', rcp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==2):
            print('\n\t\t\tRava Pongal')
            print('\t\t\tPlease Select Orders : Rava Pongal / 40.Rs')

            a=int(input('Give Your Count : '))
            rvp = a*40
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', rvp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', rvp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==3):
            print('\n\t\t\tSamba Pongal')
            print('\t\t\tPlease Select Orders : Samba Pongal / 45.Rs')

            a=int(input('Give Your Count : '))
            spp = a*45
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', spp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', spp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')


        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==4):
        print('\n\t\t\tPoori')

        print('\t\t\tPlease Select Orders : Poori (1 set) / 30.Rs')

        a=int(input('Give Your Count : '))
        poo = a*30

        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', poo + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', poo, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==5):
        print('\n\t\t\tChapati')

        print('\t\t\tPlease Select Orders : Chapati (1 set) / 30.Rs')

        a=int(input('Give Your Count : '))
        cha = a*30

        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', cha + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', cha, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    else:
        print('Please Choose Correct Options and Try Again...')

elif(s==2):
    print('\n\t\t\tLunch')
    print('\t\t\tPlease Select Options')

    print("""\n\t\t\t1. Full Meals
          \t\t\t2. Half Meals
          \t\t\t3. Veg Briyani
          \t\t\t4. Curd Rice
          \t\t\t5. Lemon Rice """)
    s=int(input('Please Select options : '))
    if(s==1):
        print('\n\t\t\tFull Meals')
        print('\t\t\tPlease Select Orders : Full Meals / 70.Rs')

        a=int(input('Give Your Count : '))
        fm = a*70
        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', fm + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', fm, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    elif(s==2):
        print('\n\t\t\tHalf Meals')
        print('\t\t\tPlease Select Orders : Half Meals / 50.Rs')

        a=int(input('Give Your Count : '))
        hfm = a*50
        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', hfm + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', hfm, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    elif(s==3):
        print('\n\t\t\tVeg Briyani')
        print('\t\t\tPlease Select Orders : Veg Briyani / 50.Rs')

        a=int(input('Give Your Count : '))
        vb = a*50
        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', vb + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', vb, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    elif(s==4):
        print('\n\t\t\tCurd Rice')
        print('\t\t\tPlease Select Orders : Curd Rice / 40.Rs')

        a=int(input('Give Your Count : '))
        cr = a*40
        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', cr + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', cr, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    elif(s==5):
        print('\n\t\t\tLemon Rice')
        print('\t\t\tPlease Select Orders : Lemon Rice / 40.Rs')

        a=int(input('Give Your Count : '))
        lr = a*40
        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', lr + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', lr, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    else:
        print('Please Choose Correct Options and Try Again...')

elif(s==3):
    print('\n\t\t\tDinner')
    print('\t\t\tPlease Select Options')

    print("""\n\t\t\t\t1. Idly
          \t\t\t2. Dosa
          \t\t\t3. Parota
          \t\t\t4. Chapati """)
    s=int(input('Please Select options : '))

    if (s==1):
        print('\n\t\t\tIdly')
        print('\t\t\tPlease Select Options')

        print("""\n\t\t\t\t1. Rice Idly
              \t\t\t2. Rava Idly
              \t\t\t3. Samba Idly""")
        s=int(input('Please Select options : '))
        if (s==1):
            print('\n\t\t\tRice Idly')
            print('\t\t\tPlease Select Orders : Rice Idly / 10.Rs')

            a=int(input('Give Your Count : '))
            ip = a*10
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', ip + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', ip, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==2):
            print('\n\t\t\tRava Idly')
            print('\t\t\tPlease Select Orders : Rava Idly / 15.Rs')

            a=int(input('Give Your Count : '))
            rdp = a*15
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', rdp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', rdp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==3):
            print('\n\t\t\tSamba Idly')
            print('\t\t\tPlease Select Orders : Samba Idly / 20.Rs')

            a=int(input('Give Your Count : '))
            sdp = a*20
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', sdp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', sdp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')


        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==2):
        print('\n\t\t\tDosa')
        print('\t\t\tPlease Select Options')

        print("""\n\t\t\t\t1. Ordinary Dosa
              \t\t\t2. Rava Dosa
              \t\t\t3. Ghee Dosa
              \t\t\t4. Onion Dosa
              \t\t\t5. Spl. Dosa""")
        s=int(input('Please Select options : '))
        if (s==1):
            print('\n\t\t\tOrdinary Dosa')
            print('\t\t\tPlease Select Orders : Ordinary Dosa / 30.Rs')

            d=int(input('Give Your Count : '))
            dp = d*10
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', dp + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', dp, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==2):
            print('\n\t\t\tRava Dosa')
            print('\t\t\tPlease Select Orders : Rava Dosa / 30.Rs')

            a=int(input('Give Your Count : '))
            rd = a*30
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', rd + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', rd, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==3):
            print('\n\t\t\tGhee Dosa')
            print('\t\t\tPlease Select Orders : Ghee Dosa / 45.Rs')

            a=int(input('Give Your Count : '))
            gd = a*45
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', gd + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', gd, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==4):
            print('\n\t\t\tOnion Dosa')
            print('\t\t\tPlease Select Orders : Onion Dosa / 40.Rs')

            a=int(input('Give Your Count : '))
            od = a*40
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', od + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif (v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', od, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')

        elif (s==5):
            print('\n\t\t\tSpl. Dosa')
            print('\t\t\tPlease Select Orders : Spl. Dos / 50.Rs')

            a=int(input('Give Your Count : '))
            spd = a*50
            print('\t\t\tVada / 10.Rs Only ...')
            v=str(input('You Want Vada ...  (Yes or No)  :  '))

            if (v=="yes" or v=="YES" or v=="Yes"):
                vada=int(input('Give Your Count : '))
                vp= vada * 10
                print('Your Order Details: ', spd + vp, 'Rupees Only...')
                print("\nDon't waste foods...")
            elif(v=="no" or v=="NO" or v=="No"):
                print('Your Order Details: ', spd, 'Rupees Only...')
                print("\nDon't waste foods...")
            else:
                print('Please Choose Correct Options and Try Again...')


        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==3):
        print('\n\t\t\tParota')

        print('\t\t\tPlease Select Orders : Parota (1 set) / 40.Rs')

        a=int(input('Give Your Count : '))
        par = a*40

        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', par + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', par, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    elif (s==4):
        print('\n\t\t\tChapati')

        print('\t\t\tPlease Select Orders : Chapati (1 set) / 30.Rs')

        a=int(input('Give Your Count : '))
        cha = a*30

        print('\t\t\tVada / 10.Rs Only ...')
        v=str(input('You Want Vada ...  (Yes or No)  :  '))

        if (v=="yes" or v=="YES" or v=="Yes"):
            vada=int(input('Give Your Count : '))
            vp= vada * 10
            print('Your Order Details: ', cha + vp, 'Rupees Only...')
            print("\nDon't waste foods...")
        elif (v=="no" or v=="NO" or v=="No"):
            print('Your Order Details: ', cha, 'Rupees Only...')
            print("\nDon't waste foods...")
        else:
            print('Please Choose Correct Options and Try Again...')

    else:
        print('Please Choose Correct Options and Try Again...')

else:
    print('Please Choose Correct Options and Try Again...')
# Out:
# 			welcome to
# 			SUDHAN FOOD
# 			...Thank You For Choosing Us...
#
# 			Please Select Options
# 			1. Tiffin
#       			2. Lunch
#       			3. Dinner
# Give Your Options : 3
#
# 			Dinner
# 			Please Select Options
#
# 				1. Idly
#           			2. Dosa
#           			3. Parota
#           			4. Chapati
# Please Select options : 1
#
# 			Idly
# 			Please Select Options
#
# 				1. Rice Idly
#               			2. Rava Idly
#               			3. Samba Idly
# Please Select options : 1
#
# 			Rice Idly
# 			Please Select Orders : Rice Idly / 10.Rs
# Give Your Count : 3
# 			Vada / 10.Rs Only ...
# You Want Vada ...  (Yes or No)  :  yes
# Give Your Count : 3
# Your Order Details:  60 Rupees Only...
#
# Don't waste foods...
